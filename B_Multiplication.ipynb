# %% [markdown]
# Group Name: AceIt
# Group members: 1. Kashish Jethmalani AU2140029
#                2. Jeel Kadivar AU2140181
#                3. Milan Godhaviya AU2140078
#                4. Shrey Bhadja AU2140030
#                5. Vishwa Joshi AU2140112
#
# Question B is contributed by Shrey Bhadja AU2140030, Milan Godhaviya AU2140078

# %%
# B: Multipliction of matrix

# Taking inputs
for i in range(int(input("Enter the number of test cases : "))):
    A = []
    rowsOfA = int(input("Number of rows of matrix A: "))
    colsOfA = int(input("Number of cols of matrix A: "))
    for i in range(rowsOfA):
        temp = []
        for j in range(colsOfA):
            temp.append(int(input(f"enter element {i+1} {j+1} : ")))
        A.append(temp)

    B = []
    rowsOfB = int(input("Number of rows of matrix B: "))
    colsOfB = int(input("Number of cols of matrix B: "))
    for i in range(rowsOfB):
        temp = []
        for j in range(colsOfB):
            temp.append(int(input(f"enter element {i+1} {j+1} : ")))
        B.append(temp)

    if colsOfA == rowsOfB:
        result = []
        # making a empty matrix
        for i in range(rowsOfA):
            temp = []
            for j in range(colsOfB):
                temp.append(0)
            result.append(temp)

        # Multipliying
        for i in range(len(A)):
            for j in range(len(B[0])):
                for k in range(len(B)):
                    result[i][j] += A[i][k] * B[k][j]

        for r in result:
            print(r)
    else:
        print("Enter a valid Input!")

"""

Output : 

Enter the number of test cases : 2
Number of rows of matrix A: 4
Number of cols of matrix A: 4
enter element 1 1 : 0
enter element 1 2 : 1
enter element 1 3 : 2
enter element 1 4 : 3
enter element 2 1 : 4
enter element 2 2 : 5
enter element 2 3 : 6
enter element 2 4 : 7
enter element 3 1 : 8
enter element 3 2 : 9
enter element 3 3 : 0
enter element 3 4 : 1
enter element 4 1 : 0
enter element 4 2 : 0
enter element 4 3 : 4
enter element 4 4 : 7
Number of rows of matrix B: 4
Number of cols of matrix B: 4
enter element 1 1 : 0
enter element 1 2 : 1
enter element 1 3 : 2
enter element 1 4 : 36
enter element 2 1 : 3
enter element 2 2 : 2
enter element 2 3 : 8
enter element 2 4 : 9
enter element 3 1 : 0
enter element 3 2 : 2
enter element 3 3 : 3
enter element 3 4 : 4
enter element 4 1 : 1
enter element 4 2 : 7
enter element 4 3 : 2
enter element 4 4 : 4
[6, 27, 20, 29]
[22, 75, 80, 241]
[28, 33, 90, 373]
[7, 57, 26, 44]
Number of rows of matrix A: 5
Number of cols of matrix A: 5
enter element 1 1 : 0
enter element 1 2 : 1
enter element 1 3 : 9
enter element 1 4 : 8
enter element 1 5 : 7
enter element 2 1 : 6
enter element 2 2 : 5
enter element 2 3 : 4
enter element 2 4 : 3
enter element 2 5 : 2
enter element 3 1 : 1
enter element 3 2 : 6
enter element 3 3 : 7
enter element 3 4 : 8
enter element 3 5 : 9
enter element 4 1 : 0
enter element 4 2 : 1
enter element 4 3 : 1
enter element 4 4 : 1
enter element 4 5 : 2
enter element 5 1 : 8
enter element 5 2 : 3
enter element 5 3 : 9
enter element 5 4 : 2
enter element 5 5 : 2
Number of rows of matrix B: 5
Number of cols of matrix B: 5
enter element 1 1 : 0
enter element 1 2 : 1
enter element 1 3 : 9
enter element 1 4 : 6
enter element 1 5 : 3
enter element 2 1 : 4
enter element 2 2 : 5
enter element 2 3 : 7
enter element 2 4 : 9
enter element 2 5 : 2
enter element 3 1 : 3
enter element 3 2 : 4
enter element 3 3 : 6
enter element 3 4 : 5
enter element 3 5 : 7
enter element 4 1 : 8
enter element 4 2 : 9
enter element 4 3 : 1
enter element 4 4 : 2
enter element 4 5 : 3
enter element 5 1 : 4
enter element 5 2 : 5
enter element 5 3 : 0
enter element 5 4 : 0
enter element 5 5 : 5
[123, 148, 69, 70, 124]
[64, 84, 116, 107, 75]
[145, 176, 101, 111, 133]
[23, 28, 14, 16, 22]
[63, 87, 149, 124, 109]

"""

# %% [markdown]
# ![b1.png](data:image/png;base64,...)

# %% [markdown]
# ![b2.png](data:image/png;base64,...)
