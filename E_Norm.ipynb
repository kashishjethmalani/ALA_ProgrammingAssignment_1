# %%
Group Name: AceIt
Group members: 1. Kashish Jethmalani AU2140029
               2. Jeel Kadivar AU2140181
               3. Milan Godhaviya AU2140078
               4. Shrey Bhadja AU2140030
               5. Vishwa Joshi AU2140112

 Question E is contributed by Kashish Jethmalani AU2140029, Shrey Bhadja AU2140030.

# %%
# E: Norm of matrix

# Taking inputs of size m x n
for i in range(int(input("Enter the number of the test cases : "))):
    A = []
    rows = int(input("Number of rows of matrix : "))
    cols = int(input("Number of cols of matrix : "))
    for i in range(rows):
        temp = []
        for j in range(cols):
            temp.append(int(input(f"enter element {i+1} {j+1} : ")))
        A.append(temp)

    # Taking Transpose
    A_trans = []
    # making a empty matrix of size n x m
    for i in range(cols):
        temp = []
        for j in range(rows):
            temp.append(A[j][i])
        A_trans.append(temp)

    # Multipliying A and A-transpose
    result = []
    # Making an empty matrix of size m x m
    for i in range(rows):
        temp = []
        for j in range(rows):
            temp.append(0)
        result.append(temp)

    # multipliying
    for i in range(len(A)):
        for j in range(len(A_trans[0])):
            for k in range(len(A_trans)):
                result[i][j] += A[i][k] * A_trans[k][j]

    # adding diagonals and taking root
    sum = 0
    for i in range(rows):
        for j in range(cols):
            if i == j:
                sum += result[i][j]
    print("Root of ", sum)
    print(" =", sum ** (1 / 2))

    """
Output : 
Enter the number of the test cases : 3    
Number of rows of matrix :  4
Number of cols of matrix :  4
enter element 1 1 :  2
enter element 1 2 :  1
enter element 1 3 :  3
enter element 1 4 :  4
enter element 2 1 :  5
enter element 2 2 :  6
enter element 2 3 :  7
enter element 2 4 :  2
enter element 3 1 :  4
enter element 3 2 :  5
enter element 3 3 :  1
enter element 3 4 :  41
enter element 4 1 :  21
enter element 4 2 :  3
enter element 4 3 :  5
enter element 4 4 :  41
Root of  4023
 = 63.42712353559792
Number of rows of matrix :  4
Number of cols of matrix :  4
enter element 1 1 :  1
enter element 1 2 :  2
enter element 1 3 :  4
enter element 1 4 :  5
enter element 2 1 :  3
enter element 2 2 :  1
enter element 2 3 :  4
enter element 2 4 :  2
enter element 3 1 :  3
enter element 3 2 :  5
enter element 3 3 :  4
enter element 3 4 :  4
enter element 4 1 :  1
enter element 4 2 :  2
enter element 4 3 :  3
enter element 4 4 :  2
Root of  160
 = 12.649110640673518
Number of rows of matrix :  5
Number of cols of matrix :  5
enter element 1 1 :  1
enter element 1 2 :  4
enter element 1 3 :  2
enter element 1 4 :  4
enter element 1 5 :  5
enter element 2 1 :  3
enter element 2 2 :  5
enter element 2 3 :  4
enter element 2 4 :  1
enter element 2 5 :  2
enter element 3 1 :  5
enter element 3 2 :  3
enter element 3 3 :  5
enter element 3 4 :  5
enter element 3 5 :  1
enter element 4 1 :  4
enter element 4 2 :  2
enter element 4 3 :  3
enter element 4 4 :  4
enter element 4 5 :  5
enter element 5 1 :  1
enter element 5 2 :  4
enter element 5 3 :  2
enter element 5 4 :  5
enter element 5 5 :  31
Root of  1279
 = 35.76310948449533"""

# %% [markdown]
# ![e1_.png](data:image/png;base64,...)

# %% [markdown]
# ![e2.png](data:image/png;base64,...)

# %% [markdown]
# ![e3.png](data:image/png;base64,...)
